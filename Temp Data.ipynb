# %%
from rasterstats import zonal_stats
import geopandas
import json
import pandas as pd
import copy

# %%
country = geopandas.read_file('/Users/noahgonzales/Desktop/us_states.json')
country = country.to_crs(epsg=4269) 
country = country[(country.NAME=="Iowa")|\
                  (country.NAME=="Illinois")|\
                  (country.NAME=="Nebraska")|\
                  (country.NAME=="Minnesota")|\
                  (country.NAME=="Indiana")|\
                  (country.NAME=="Kansas")|\
                  (country.NAME=="South Dakota")|\
                  (country.NAME=="Ohio")|\
                  (country.NAME=="Missouri")|\
                  (country.NAME=="Wisconsin")]

# %%
##Zonal stats for 01/08-04/08
zonal_stats0108=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200801_bil.bil')
zonal_stats0108 = pd.DataFrame(zonal_stats0108)
zonal_stats0108.columns = ["temp_"+x for x in zonal_stats0108.columns]
zonal_stats0108.index = country.index
zonal_stats0108 = pd.concat([country,zonal_stats0108],axis=1)

zonal_stats0208=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200802_bil.bil')
zonal_stats0208 = pd.DataFrame(zonal_stats0208)
zonal_stats0208.columns = ["temp_"+x for x in zonal_stats0208.columns]
zonal_stats0208.index = country.index
zonal_stats0208 = pd.concat([country,zonal_stats0208],axis=1)

zonal_stats0308=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200803_bil.bil')
zonal_stats0308 = pd.DataFrame(zonal_stats0308)
zonal_stats0308.columns = ["temp_"+x for x in zonal_stats0308.columns]
zonal_stats0308.index = country.index
zonal_stats0308 = pd.concat([country,zonal_stats0308],axis=1)

zonal_stats0408=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200804_bil.bil')
zonal_stats0408 = pd.DataFrame(zonal_stats0408)
zonal_stats0408.columns = ["temp_"+x for x in zonal_stats0408.columns]
zonal_stats0408.index = country.index
zonal_stats0408 = pd.concat([country,zonal_stats0408],axis=1)

zonal_stats0508=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200805_bil.bil')
zonal_stats0508 = pd.DataFrame(zonal_stats0508)
zonal_stats0508.columns = ["temp_"+x for x in zonal_stats0508.columns]
zonal_stats0508.index = country.index
zonal_stats0508 = pd.concat([country,zonal_stats0508],axis=1)

zonal_stats0608=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200806_bil.bil')
zonal_stats0608 = pd.DataFrame(zonal_stats0608)
zonal_stats0608.columns = ["temp_"+x for x in zonal_stats0608.columns]
zonal_stats0608.index = country.index
zonal_stats0608 = pd.concat([country,zonal_stats0608],axis=1)

zonal_stats0708=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200807_bil.bil')
zonal_stats0708 = pd.DataFrame(zonal_stats0708)
zonal_stats0708.columns = ["temp_"+x for x in zonal_stats0708.columns]
zonal_stats0708.index = country.index
zonal_stats0708 = pd.concat([country,zonal_stats0708],axis=1)

zonal_stats0808=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200808_bil.bil')
zonal_stats0808 = pd.DataFrame(zonal_stats0808)
zonal_stats0808.columns = ["temp_"+x for x in zonal_stats0808.columns]
zonal_stats0808.index = country.index
zonal_stats0808 = pd.concat([country,zonal_stats0808],axis=1)

zonal_stats0908=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200809_bil.bil')
zonal_stats0908 = pd.DataFrame(zonal_stats0908)
zonal_stats0908.columns = ["temp_"+x for x in zonal_stats0908.columns]
zonal_stats0908.index = country.index
zonal_stats0908 = pd.concat([country,zonal_stats0908],axis=1)

zonal_stats1008=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200810_bil.bil')
zonal_stats1008 = pd.DataFrame(zonal_stats1008)
zonal_stats1008.columns = ["temp_"+x for x in zonal_stats1008.columns]
zonal_stats1008.index = country.index
zonal_stats1008 = pd.concat([country,zonal_stats1008],axis=1)

zonal_stats1108=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200811_bil.bil')
zonal_stats1108 = pd.DataFrame(zonal_stats1108)
zonal_stats1108.columns = ["temp_"+x for x in zonal_stats1108.columns]
zonal_stats1108.index = country.index
zonal_stats1108 = pd.concat([country,zonal_stats1108],axis=1)

zonal_stats1208=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2008/PRISM_tmean_stable_4kmM3_200812_bil.bil')
zonal_stats1208 = pd.DataFrame(zonal_stats1208)
zonal_stats1208.columns = ["temp_"+x for x in zonal_stats1208.columns]
zonal_stats1208.index = country.index
zonal_stats1208 = pd.concat([country,zonal_stats1208],axis=1)



zonal_stats0108['month']=1
zonal_stats0208['month']=2
zonal_stats0308['month']=3
zonal_stats0408['month']=4
zonal_stats0508['month']=5
zonal_stats0608['month']=6
zonal_stats0708['month']=7
zonal_stats0808['month']=8
zonal_stats0908['month']=9
zonal_stats1008['month']=10
zonal_stats1108['month']=11
zonal_stats1208['month']=12


zonal_stats08=copy.deepcopy(zonal_stats0108)
zonal_stats08=zonal_stats08.append([zonal_stats0208,zonal_stats0308,zonal_stats0408,zonal_stats0508,zonal_stats0608,\
                                   zonal_stats0708,zonal_stats0808,zonal_stats0908,zonal_stats1008,\
                                   zonal_stats1108,zonal_stats1208],ignore_index=True)

zonal_stats08['year']=2008

# %%
##Zonal stats for 01/09-04/09
zonal_stats0109=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200901_bil.bil')
zonal_stats0109 = pd.DataFrame(zonal_stats0109)
zonal_stats0109.columns = ["temp_"+x for x in zonal_stats0109.columns]
zonal_stats0109.index = country.index
zonal_stats0109 = pd.concat([country,zonal_stats0109],axis=1)

zonal_stats0209=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200902_bil.bil')
zonal_stats0209 = pd.DataFrame(zonal_stats0209)
zonal_stats0209.columns = ["temp_"+x for x in zonal_stats0209.columns]
zonal_stats0209.index = country.index
zonal_stats0209 = pd.concat([country,zonal_stats0209],axis=1)

zonal_stats0309=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200903_bil.bil')
zonal_stats0309 = pd.DataFrame(zonal_stats0309)
zonal_stats0309.columns = ["temp_"+x for x in zonal_stats0309.columns]
zonal_stats0309.index = country.index
zonal_stats0309 = pd.concat([country,zonal_stats0309],axis=1)

zonal_stats0409=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200904_bil.bil')
zonal_stats0409 = pd.DataFrame(zonal_stats0409)
zonal_stats0409.columns = ["temp_"+x for x in zonal_stats0409.columns]
zonal_stats0409.index = country.index
zonal_stats0409 = pd.concat([country,zonal_stats0409],axis=1)

zonal_stats0509=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200905_bil.bil')
zonal_stats0509 = pd.DataFrame(zonal_stats0509)
zonal_stats0509.columns = ["temp_"+x for x in zonal_stats0509.columns]
zonal_stats0509.index = country.index
zonal_stats0509 = pd.concat([country,zonal_stats0509],axis=1)

zonal_stats0609=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200906_bil.bil')
zonal_stats0609 = pd.DataFrame(zonal_stats0609)
zonal_stats0609.columns = ["temp_"+x for x in zonal_stats0609.columns]
zonal_stats0609.index = country.index
zonal_stats0609 = pd.concat([country,zonal_stats0609],axis=1)

zonal_stats0709=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200907_bil.bil')
zonal_stats0709 = pd.DataFrame(zonal_stats0709)
zonal_stats0709.columns = ["temp_"+x for x in zonal_stats0709.columns]
zonal_stats0709.index = country.index
zonal_stats0709 = pd.concat([country,zonal_stats0709],axis=1)

zonal_stats0809=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200908_bil.bil')
zonal_stats0809 = pd.DataFrame(zonal_stats0809)
zonal_stats0809.columns = ["temp_"+x for x in zonal_stats0809.columns]
zonal_stats0809.index = country.index
zonal_stats0809 = pd.concat([country,zonal_stats0809],axis=1)

zonal_stats0909=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200909_bil.bil')
zonal_stats0909 = pd.DataFrame(zonal_stats0909)
zonal_stats0909.columns = ["temp_"+x for x in zonal_stats0909.columns]
zonal_stats0909.index = country.index
zonal_stats0909 = pd.concat([country,zonal_stats0909],axis=1)

zonal_stats1009=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200910_bil.bil')
zonal_stats1009 = pd.DataFrame(zonal_stats1009)
zonal_stats1009.columns = ["temp_"+x for x in zonal_stats1009.columns]
zonal_stats1009.index = country.index
zonal_stats1009 = pd.concat([country,zonal_stats1009],axis=1)

zonal_stats1109=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200911_bil.bil')
zonal_stats1109 = pd.DataFrame(zonal_stats1109)
zonal_stats1109.columns = ["temp_"+x for x in zonal_stats1109.columns]
zonal_stats1109.index = country.index
zonal_stats1109 = pd.concat([country,zonal_stats1109],axis=1)

zonal_stats1209=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2009/PRISM_tmean_stable_4kmM3_200912_bil.bil')
zonal_stats1209 = pd.DataFrame(zonal_stats1209)
zonal_stats1209.columns = ["temp_"+x for x in zonal_stats1209.columns]
zonal_stats1209.index = country.index
zonal_stats1209 = pd.concat([country,zonal_stats1209],axis=1)



zonal_stats0109['month']=1
zonal_stats0209['month']=2
zonal_stats0309['month']=3
zonal_stats0409['month']=4
zonal_stats0509['month']=5
zonal_stats0609['month']=6
zonal_stats0709['month']=7
zonal_stats0809['month']=8
zonal_stats0909['month']=9
zonal_stats1009['month']=10
zonal_stats1109['month']=11
zonal_stats1209['month']=12


zonal_stats09=copy.deepcopy(zonal_stats0109)
zonal_stats09=zonal_stats09.append([zonal_stats0209,zonal_stats0309,zonal_stats0409,zonal_stats0509,zonal_stats0609,\
                                   zonal_stats0709,zonal_stats0809,zonal_stats0909,zonal_stats1009,\
                                   zonal_stats1109,zonal_stats1209],ignore_index=True)
                                   
                                   
zonal_stats09['year']=2009

# %%
##Zonal stats for 01/10-04/10
zonal_stats0110=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201001_bil.bil')
zonal_stats0110 = pd.DataFrame(zonal_stats0110)
zonal_stats0110.columns = ["temp_"+x for x in zonal_stats0110.columns]
zonal_stats0110.index = country.index
zonal_stats0110 = pd.concat([country,zonal_stats0110],axis=1)

zonal_stats0210=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201002_bil.bil')
zonal_stats0210 = pd.DataFrame(zonal_stats0210)
zonal_stats0210.columns = ["temp_"+x for x in zonal_stats0210.columns]
zonal_stats0210.index = country.index
zonal_stats0210 = pd.concat([country,zonal_stats0210],axis=1)

zonal_stats0310=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201003_bil.bil')
zonal_stats0310 = pd.DataFrame(zonal_stats0310)
zonal_stats0310.columns = ["temp_"+x for x in zonal_stats0310.columns]
zonal_stats0310.index = country.index
zonal_stats0310 = pd.concat([country,zonal_stats0310],axis=1)

zonal_stats0410=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201004_bil.bil')
zonal_stats0410 = pd.DataFrame(zonal_stats0410)
zonal_stats0410.columns = ["temp_"+x for x in zonal_stats0410.columns]
zonal_stats0410.index = country.index
zonal_stats0410 = pd.concat([country,zonal_stats0410],axis=1)

zonal_stats0510=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201005_bil.bil')
zonal_stats0510 = pd.DataFrame(zonal_stats0510)
zonal_stats0510.columns = ["temp_"+x for x in zonal_stats0510.columns]
zonal_stats0510.index = country.index
zonal_stats0510 = pd.concat([country,zonal_stats0510],axis=1)

zonal_stats0610=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201006_bil.bil')
zonal_stats0610 = pd.DataFrame(zonal_stats0610)
zonal_stats0610.columns = ["temp_"+x for x in zonal_stats0610.columns]
zonal_stats0610.index = country.index
zonal_stats0610 = pd.concat([country,zonal_stats0610],axis=1)

zonal_stats0710=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201007_bil.bil')
zonal_stats0710 = pd.DataFrame(zonal_stats0710)
zonal_stats0710.columns = ["temp_"+x for x in zonal_stats0710.columns]
zonal_stats0710.index = country.index
zonal_stats0710 = pd.concat([country,zonal_stats0710],axis=1)

zonal_stats0810=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201008_bil.bil')
zonal_stats0810 = pd.DataFrame(zonal_stats0810)
zonal_stats0810.columns = ["temp_"+x for x in zonal_stats0810.columns]
zonal_stats0810.index = country.index
zonal_stats0810 = pd.concat([country,zonal_stats0810],axis=1)

zonal_stats0910=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201009_bil.bil')
zonal_stats0910 = pd.DataFrame(zonal_stats0910)
zonal_stats0910.columns = ["temp_"+x for x in zonal_stats0910.columns]
zonal_stats0910.index = country.index
zonal_stats0910 = pd.concat([country,zonal_stats0910],axis=1)

zonal_stats1010=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201011_bil.bil')
zonal_stats1010 = pd.DataFrame(zonal_stats1010)
zonal_stats1010.columns = ["temp_"+x for x in zonal_stats1010.columns]
zonal_stats1010.index = country.index
zonal_stats1010 = pd.concat([country,zonal_stats1010],axis=1)

zonal_stats1110=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201011_bil.bil')
zonal_stats1110 = pd.DataFrame(zonal_stats1110)
zonal_stats1110.columns = ["temp_"+x for x in zonal_stats1110.columns]
zonal_stats1110.index = country.index
zonal_stats1110 = pd.concat([country,zonal_stats1110],axis=1)

zonal_stats1210=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2010/PRISM_tmean_stable_4kmM3_201012_bil.bil')
zonal_stats1210 = pd.DataFrame(zonal_stats1210)
zonal_stats1210.columns = ["temp_"+x for x in zonal_stats1210.columns]
zonal_stats1210.index = country.index
zonal_stats1210 = pd.concat([country,zonal_stats1210],axis=1)



zonal_stats0110['month']=1
zonal_stats0210['month']=2
zonal_stats0310['month']=3
zonal_stats0410['month']=4
zonal_stats0510['month']=5
zonal_stats0610['month']=6
zonal_stats0710['month']=7
zonal_stats0810['month']=8
zonal_stats0910['month']=9
zonal_stats1010['month']=10
zonal_stats1110['month']=11
zonal_stats1210['month']=12


zonal_stats10=copy.deepcopy(zonal_stats0110)
zonal_stats10=zonal_stats10.append([zonal_stats0210,zonal_stats0310,zonal_stats0410,zonal_stats0510,zonal_stats0610,\
                                   zonal_stats0710,zonal_stats0910,zonal_stats1010,zonal_stats1110,\
                                   zonal_stats1210,zonal_stats1210],ignore_index=True)

zonal_stats10['year']=2010

# %%
##Zonal stats for 01/11-04/11
zonal_stats0111=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201101_bil.bil')
zonal_stats0111 = pd.DataFrame(zonal_stats0111)
zonal_stats0111.columns = ["temp_"+x for x in zonal_stats0111.columns]
zonal_stats0111.index = country.index
zonal_stats0111 = pd.concat([country,zonal_stats0111],axis=1)

zonal_stats0211=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201102_bil.bil')
zonal_stats0211 = pd.DataFrame(zonal_stats0211)
zonal_stats0211.columns = ["temp_"+x for x in zonal_stats0211.columns]
zonal_stats0211.index = country.index
zonal_stats0211 = pd.concat([country,zonal_stats0211],axis=1)

zonal_stats0311=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201103_bil.bil')
zonal_stats0311 = pd.DataFrame(zonal_stats0311)
zonal_stats0311.columns = ["temp_"+x for x in zonal_stats0311.columns]
zonal_stats0311.index = country.index
zonal_stats0311 = pd.concat([country,zonal_stats0311],axis=1)

zonal_stats0411=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201104_bil.bil')
zonal_stats0411 = pd.DataFrame(zonal_stats0411)
zonal_stats0411.columns = ["temp_"+x for x in zonal_stats0411.columns]
zonal_stats0411.index = country.index
zonal_stats0411 = pd.concat([country,zonal_stats0411],axis=1)

zonal_stats0511=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201105_bil.bil')
zonal_stats0511 = pd.DataFrame(zonal_stats0511)
zonal_stats0511.columns = ["temp_"+x for x in zonal_stats0511.columns]
zonal_stats0511.index = country.index
zonal_stats0511 = pd.concat([country,zonal_stats0511],axis=1)

zonal_stats0611=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201106_bil.bil')
zonal_stats0611 = pd.DataFrame(zonal_stats0611)
zonal_stats0611.columns = ["temp_"+x for x in zonal_stats0611.columns]
zonal_stats0611.index = country.index
zonal_stats0611 = pd.concat([country,zonal_stats0611],axis=1)

zonal_stats0711=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201107_bil.bil')
zonal_stats0711 = pd.DataFrame(zonal_stats0711)
zonal_stats0711.columns = ["temp_"+x for x in zonal_stats0711.columns]
zonal_stats0711.index = country.index
zonal_stats0711 = pd.concat([country,zonal_stats0711],axis=1)

zonal_stats0811=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201108_bil.bil')
zonal_stats0811 = pd.DataFrame(zonal_stats0811)
zonal_stats0811.columns = ["temp_"+x for x in zonal_stats0811.columns]
zonal_stats0811.index = country.index
zonal_stats0811 = pd.concat([country,zonal_stats0811],axis=1)

zonal_stats0911=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201109_bil.bil')
zonal_stats0911 = pd.DataFrame(zonal_stats0911)
zonal_stats0911.columns = ["temp_"+x for x in zonal_stats0911.columns]
zonal_stats0911.index = country.index
zonal_stats0911 = pd.concat([country,zonal_stats0911],axis=1)

zonal_stats1011=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201110_bil.bil')
zonal_stats1011 = pd.DataFrame(zonal_stats1011)
zonal_stats1011.columns = ["temp_"+x for x in zonal_stats1011.columns]
zonal_stats1011.index = country.index
zonal_stats1011 = pd.concat([country,zonal_stats1011],axis=1)

zonal_stats1111=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201111_bil.bil')
zonal_stats1111 = pd.DataFrame(zonal_stats1111)
zonal_stats1111.columns = ["temp_"+x for x in zonal_stats1111.columns]
zonal_stats1111.index = country.index
zonal_stats1111 = pd.concat([country,zonal_stats1111],axis=1)

zonal_stats1211=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2011/PRISM_tmean_stable_4kmM3_201112_bil.bil')
zonal_stats1211 = pd.DataFrame(zonal_stats1211)
zonal_stats1211.columns = ["temp_"+x for x in zonal_stats1211.columns]
zonal_stats1211.index = country.index
zonal_stats1211 = pd.concat([country,zonal_stats1211],axis=1)



zonal_stats0111['month']=1
zonal_stats0211['month']=2
zonal_stats0311['month']=3
zonal_stats0411['month']=4
zonal_stats0511['month']=5
zonal_stats0611['month']=6
zonal_stats0711['month']=7
zonal_stats0811['month']=8
zonal_stats0911['month']=9
zonal_stats1011['month']=10
zonal_stats1111['month']=11
zonal_stats1211['month']=12


zonal_stats11=copy.deepcopy(zonal_stats0111)
zonal_stats11=zonal_stats11.append([zonal_stats0211,zonal_stats0311,zonal_stats0411,zonal_stats0511,zonal_stats0611,\
                                   zonal_stats0711,zonal_stats0811,zonal_stats0911,zonal_stats1011,\
                                   zonal_stats1111,zonal_stats1211],ignore_index=True)

zonal_stats11['year']=2011

# %%
##Zonal stats for 01/12-04/12
zonal_stats0112=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201201_bil.bil')
zonal_stats0112 = pd.DataFrame(zonal_stats0112)
zonal_stats0112.columns = ["temp_"+x for x in zonal_stats0112.columns]
zonal_stats0112.index = country.index
zonal_stats0112 = pd.concat([country,zonal_stats0112],axis=1)

zonal_stats0212=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201202_bil.bil')
zonal_stats0212 = pd.DataFrame(zonal_stats0212)
zonal_stats0212.columns = ["temp_"+x for x in zonal_stats0212.columns]
zonal_stats0212.index = country.index
zonal_stats0212 = pd.concat([country,zonal_stats0212],axis=1)

zonal_stats0312=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201203_bil.bil')
zonal_stats0312 = pd.DataFrame(zonal_stats0312)
zonal_stats0312.columns = ["temp_"+x for x in zonal_stats0312.columns]
zonal_stats0312.index = country.index
zonal_stats0312 = pd.concat([country,zonal_stats0312],axis=1)

zonal_stats0412=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201204_bil.bil')
zonal_stats0412 = pd.DataFrame(zonal_stats0412)
zonal_stats0412.columns = ["temp_"+x for x in zonal_stats0412.columns]
zonal_stats0412.index = country.index
zonal_stats0412 = pd.concat([country,zonal_stats0412],axis=1)

zonal_stats0512=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201205_bil.bil')
zonal_stats0512 = pd.DataFrame(zonal_stats0512)
zonal_stats0512.columns = ["temp_"+x for x in zonal_stats0512.columns]
zonal_stats0512.index = country.index
zonal_stats0512 = pd.concat([country,zonal_stats0512],axis=1)

zonal_stats0612=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201206_bil.bil')
zonal_stats0612 = pd.DataFrame(zonal_stats0612)
zonal_stats0612.columns = ["temp_"+x for x in zonal_stats0612.columns]
zonal_stats0612.index = country.index
zonal_stats0612 = pd.concat([country,zonal_stats0612],axis=1)

zonal_stats0712=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201207_bil.bil')
zonal_stats0712 = pd.DataFrame(zonal_stats0712)
zonal_stats0712.columns = ["temp_"+x for x in zonal_stats0712.columns]
zonal_stats0712.index = country.index
zonal_stats0712 = pd.concat([country,zonal_stats0712],axis=1)

zonal_stats0812=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201208_bil.bil')
zonal_stats0812 = pd.DataFrame(zonal_stats0812)
zonal_stats0812.columns = ["temp_"+x for x in zonal_stats0812.columns]
zonal_stats0812.index = country.index
zonal_stats0812 = pd.concat([country,zonal_stats0812],axis=1)

zonal_stats0912=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201209_bil.bil')
zonal_stats0912 = pd.DataFrame(zonal_stats0912)
zonal_stats0912.columns = ["temp_"+x for x in zonal_stats0912.columns]
zonal_stats0912.index = country.index
zonal_stats0912 = pd.concat([country,zonal_stats0912],axis=1)

zonal_stats1012=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201210_bil.bil')
zonal_stats1012 = pd.DataFrame(zonal_stats1012)
zonal_stats1012.columns = ["temp_"+x for x in zonal_stats1012.columns]
zonal_stats1012.index = country.index
zonal_stats1012 = pd.concat([country,zonal_stats1012],axis=1)

zonal_stats1112=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201211_bil.bil')
zonal_stats1112 = pd.DataFrame(zonal_stats1112)
zonal_stats1112.columns = ["temp_"+x for x in zonal_stats1112.columns]
zonal_stats1112.index = country.index
zonal_stats1112 = pd.concat([country,zonal_stats1112],axis=1)

zonal_stats1212=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2012/PRISM_tmean_stable_4kmM3_201212_bil.bil')
zonal_stats1212 = pd.DataFrame(zonal_stats1212)
zonal_stats1212.columns = ["temp_"+x for x in zonal_stats1212.columns]
zonal_stats1212.index = country.index
zonal_stats1212 = pd.concat([country,zonal_stats1212],axis=1)



zonal_stats0112['month']=1
zonal_stats0212['month']=2
zonal_stats0312['month']=3
zonal_stats0412['month']=4
zonal_stats0512['month']=5
zonal_stats0612['month']=6
zonal_stats0712['month']=7
zonal_stats0812['month']=8
zonal_stats0912['month']=9
zonal_stats1012['month']=10
zonal_stats1112['month']=11
zonal_stats1212['month']=12


zonal_stats12=copy.deepcopy(zonal_stats0112)
zonal_stats12=zonal_stats12.append([zonal_stats0212,zonal_stats0312,zonal_stats0412,zonal_stats0512,zonal_stats0612,\
                                   zonal_stats0712,zonal_stats0812,zonal_stats0912,zonal_stats1012,\
                                   zonal_stats1112,zonal_stats1212],ignore_index=True)

zonal_stats12['year']=2012

# %%
##Zonal stats for 01/13-04/13
zonal_stats0113=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201301_bil.bil')
zonal_stats0113 = pd.DataFrame(zonal_stats0113)
zonal_stats0113.columns = ["temp_"+x for x in zonal_stats0113.columns]
zonal_stats0113.index = country.index
zonal_stats0113 = pd.concat([country,zonal_stats0113],axis=1)

zonal_stats0213=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201302_bil.bil')
zonal_stats0213 = pd.DataFrame(zonal_stats0213)
zonal_stats0213.columns = ["temp_"+x for x in zonal_stats0213.columns]
zonal_stats0213.index = country.index
zonal_stats0213 = pd.concat([country,zonal_stats0213],axis=1)

zonal_stats0313=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201303_bil.bil')
zonal_stats0313 = pd.DataFrame(zonal_stats0313)
zonal_stats0313.columns = ["temp_"+x for x in zonal_stats0313.columns]
zonal_stats0313.index = country.index
zonal_stats0313 = pd.concat([country,zonal_stats0313],axis=1)

zonal_stats0413=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201304_bil.bil')
zonal_stats0413 = pd.DataFrame(zonal_stats0413)
zonal_stats0413.columns = ["temp_"+x for x in zonal_stats0413.columns]
zonal_stats0413.index = country.index
zonal_stats0413 = pd.concat([country,zonal_stats0413],axis=1)

zonal_stats0513=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201305_bil.bil')
zonal_stats0513 = pd.DataFrame(zonal_stats0513)
zonal_stats0513.columns = ["temp_"+x for x in zonal_stats0513.columns]
zonal_stats0513.index = country.index
zonal_stats0513 = pd.concat([country,zonal_stats0513],axis=1)

zonal_stats0613=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201306_bil.bil')
zonal_stats0613 = pd.DataFrame(zonal_stats0613)
zonal_stats0613.columns = ["temp_"+x for x in zonal_stats0613.columns]
zonal_stats0613.index = country.index
zonal_stats0613 = pd.concat([country,zonal_stats0613],axis=1)

zonal_stats0713=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201307_bil.bil')
zonal_stats0713 = pd.DataFrame(zonal_stats0713)
zonal_stats0713.columns = ["temp_"+x for x in zonal_stats0713.columns]
zonal_stats0713.index = country.index
zonal_stats0713 = pd.concat([country,zonal_stats0713],axis=1)

zonal_stats0813=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201308_bil.bil')
zonal_stats0813 = pd.DataFrame(zonal_stats0813)
zonal_stats0813.columns = ["temp_"+x for x in zonal_stats0813.columns]
zonal_stats0813.index = country.index
zonal_stats0813 = pd.concat([country,zonal_stats0813],axis=1)

zonal_stats0913=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201309_bil.bil')
zonal_stats0913 = pd.DataFrame(zonal_stats0913)
zonal_stats0913.columns = ["temp_"+x for x in zonal_stats0913.columns]
zonal_stats0913.index = country.index
zonal_stats0913 = pd.concat([country,zonal_stats0913],axis=1)

zonal_stats1013=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201310_bil.bil')
zonal_stats1013 = pd.DataFrame(zonal_stats1013)
zonal_stats1013.columns = ["temp_"+x for x in zonal_stats1013.columns]
zonal_stats1013.index = country.index
zonal_stats1013 = pd.concat([country,zonal_stats1013],axis=1)

zonal_stats1113=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201311_bil.bil')
zonal_stats1113 = pd.DataFrame(zonal_stats1113)
zonal_stats1113.columns = ["temp_"+x for x in zonal_stats1113.columns]
zonal_stats1113.index = country.index
zonal_stats1113 = pd.concat([country,zonal_stats1113],axis=1)

zonal_stats1213=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2013/PRISM_tmean_stable_4kmM3_201312_bil.bil')
zonal_stats1213 = pd.DataFrame(zonal_stats1213)
zonal_stats1213.columns = ["temp_"+x for x in zonal_stats1213.columns]
zonal_stats1213.index = country.index
zonal_stats1213 = pd.concat([country,zonal_stats1213],axis=1)



zonal_stats0113['month']=1
zonal_stats0213['month']=2
zonal_stats0313['month']=3
zonal_stats0413['month']=4
zonal_stats0513['month']=5
zonal_stats0613['month']=6
zonal_stats0713['month']=7
zonal_stats0813['month']=8
zonal_stats0913['month']=9
zonal_stats1013['month']=10
zonal_stats1113['month']=11
zonal_stats1213['month']=12


zonal_stats13=copy.deepcopy(zonal_stats0113)
zonal_stats13=zonal_stats13.append([zonal_stats0213,zonal_stats0313,zonal_stats0413,zonal_stats0513,zonal_stats0613,\
                                   zonal_stats0713,zonal_stats0813,zonal_stats0913,zonal_stats1013,\
                                   zonal_stats1113,zonal_stats1213],ignore_index=True)

zonal_stats13['year']=2013

# %%
##Zonal stats for 01/14-04/14
zonal_stats0114=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201401_bil.bil')
zonal_stats0114 = pd.DataFrame(zonal_stats0114)
zonal_stats0114.columns = ["temp_"+x for x in zonal_stats0114.columns]
zonal_stats0114.index = country.index
zonal_stats0114 = pd.concat([country,zonal_stats0114],axis=1)

zonal_stats0214=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201402_bil.bil')
zonal_stats0214 = pd.DataFrame(zonal_stats0214)
zonal_stats0214.columns = ["temp_"+x for x in zonal_stats0214.columns]
zonal_stats0214.index = country.index
zonal_stats0214 = pd.concat([country,zonal_stats0214],axis=1)

zonal_stats0314=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201403_bil.bil')
zonal_stats0314 = pd.DataFrame(zonal_stats0314)
zonal_stats0314.columns = ["temp_"+x for x in zonal_stats0314.columns]
zonal_stats0314.index = country.index
zonal_stats0314 = pd.concat([country,zonal_stats0314],axis=1)

zonal_stats0414=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201404_bil.bil')
zonal_stats0414 = pd.DataFrame(zonal_stats0414)
zonal_stats0414.columns = ["temp_"+x for x in zonal_stats0414.columns]
zonal_stats0414.index = country.index
zonal_stats0414 = pd.concat([country,zonal_stats0414],axis=1)

zonal_stats0514=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201405_bil.bil')
zonal_stats0514 = pd.DataFrame(zonal_stats0514)
zonal_stats0514.columns = ["temp_"+x for x in zonal_stats0514.columns]
zonal_stats0514.index = country.index
zonal_stats0514 = pd.concat([country,zonal_stats0514],axis=1)

zonal_stats0614=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201406_bil.bil')
zonal_stats0614 = pd.DataFrame(zonal_stats0614)
zonal_stats0614.columns = ["temp_"+x for x in zonal_stats0614.columns]
zonal_stats0614.index = country.index
zonal_stats0614 = pd.concat([country,zonal_stats0614],axis=1)

zonal_stats0714=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201407_bil.bil')
zonal_stats0714 = pd.DataFrame(zonal_stats0714)
zonal_stats0714.columns = ["temp_"+x for x in zonal_stats0714.columns]
zonal_stats0714.index = country.index
zonal_stats0714 = pd.concat([country,zonal_stats0714],axis=1)

zonal_stats0814=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201408_bil.bil')
zonal_stats0814 = pd.DataFrame(zonal_stats0814)
zonal_stats0814.columns = ["temp_"+x for x in zonal_stats0814.columns]
zonal_stats0814.index = country.index
zonal_stats0814 = pd.concat([country,zonal_stats0814],axis=1)

zonal_stats0914=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201409_bil.bil')
zonal_stats0914 = pd.DataFrame(zonal_stats0914)
zonal_stats0914.columns = ["temp_"+x for x in zonal_stats0914.columns]
zonal_stats0914.index = country.index
zonal_stats0914 = pd.concat([country,zonal_stats0914],axis=1)

zonal_stats1014=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201410_bil.bil')
zonal_stats1014 = pd.DataFrame(zonal_stats1014)
zonal_stats1014.columns = ["temp_"+x for x in zonal_stats1014.columns]
zonal_stats1014.index = country.index
zonal_stats1014 = pd.concat([country,zonal_stats1014],axis=1)

zonal_stats1114=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201411_bil.bil')
zonal_stats1114 = pd.DataFrame(zonal_stats1114)
zonal_stats1114.columns = ["temp_"+x for x in zonal_stats1114.columns]
zonal_stats1114.index = country.index
zonal_stats1114 = pd.concat([country,zonal_stats1114],axis=1)

zonal_stats1214=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2014/PRISM_tmean_stable_4kmM3_201412_bil.bil')
zonal_stats1214 = pd.DataFrame(zonal_stats1214)
zonal_stats1214.columns = ["temp_"+x for x in zonal_stats1214.columns]
zonal_stats1214.index = country.index
zonal_stats1214 = pd.concat([country,zonal_stats1214],axis=1)


zonal_stats0114['month']=1
zonal_stats0214['month']=2
zonal_stats0314['month']=3
zonal_stats0414['month']=4
zonal_stats0514['month']=5
zonal_stats0614['month']=6
zonal_stats0714['month']=7
zonal_stats0814['month']=8
zonal_stats0914['month']=9
zonal_stats1014['month']=10
zonal_stats1114['month']=11
zonal_stats1214['month']=12


zonal_stats14=copy.deepcopy(zonal_stats0114)
zonal_stats14=zonal_stats14.append([zonal_stats0214,zonal_stats0314,zonal_stats0414,zonal_stats0514,zonal_stats0614,\
                                   zonal_stats0714,zonal_stats0814,zonal_stats0914,zonal_stats1014,\
                                   zonal_stats1114,zonal_stats1214],ignore_index=True)

zonal_stats14['year']=2014

# %%
##Zonal stats for 01/15-04/15
zonal_stats0115=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201501_bil.bil')
zonal_stats0115 = pd.DataFrame(zonal_stats0115)
zonal_stats0115.columns = ["temp_"+x for x in zonal_stats0115.columns]
zonal_stats0115.index = country.index
zonal_stats0115 = pd.concat([country,zonal_stats0115],axis=1)

zonal_stats0215=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201502_bil.bil')
zonal_stats0215 = pd.DataFrame(zonal_stats0215)
zonal_stats0215.columns = ["temp_"+x for x in zonal_stats0215.columns]
zonal_stats0215.index = country.index
zonal_stats0215 = pd.concat([country,zonal_stats0215],axis=1)

zonal_stats0315=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201503_bil.bil')
zonal_stats0315 = pd.DataFrame(zonal_stats0315)
zonal_stats0315.columns = ["temp_"+x for x in zonal_stats0315.columns]
zonal_stats0315.index = country.index
zonal_stats0315 = pd.concat([country,zonal_stats0315],axis=1)

zonal_stats0415=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201504_bil.bil')
zonal_stats0415 = pd.DataFrame(zonal_stats0415)
zonal_stats0415.columns = ["temp_"+x for x in zonal_stats0415.columns]
zonal_stats0415.index = country.index
zonal_stats0415 = pd.concat([country,zonal_stats0415],axis=1)

zonal_stats0515=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201505_bil.bil')
zonal_stats0515 = pd.DataFrame(zonal_stats0515)
zonal_stats0515.columns = ["temp_"+x for x in zonal_stats0515.columns]
zonal_stats0515.index = country.index
zonal_stats0515 = pd.concat([country,zonal_stats0515],axis=1)

zonal_stats0615=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201506_bil.bil')
zonal_stats0615 = pd.DataFrame(zonal_stats0615)
zonal_stats0615.columns = ["temp_"+x for x in zonal_stats0615.columns]
zonal_stats0615.index = country.index
zonal_stats0615 = pd.concat([country,zonal_stats0615],axis=1)

zonal_stats0715=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201507_bil.bil')
zonal_stats0715 = pd.DataFrame(zonal_stats0715)
zonal_stats0715.columns = ["temp_"+x for x in zonal_stats0715.columns]
zonal_stats0715.index = country.index
zonal_stats0715 = pd.concat([country,zonal_stats0715],axis=1)

zonal_stats0815=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201508_bil.bil')
zonal_stats0815 = pd.DataFrame(zonal_stats0815)
zonal_stats0815.columns = ["temp_"+x for x in zonal_stats0815.columns]
zonal_stats0815.index = country.index
zonal_stats0815 = pd.concat([country,zonal_stats0815],axis=1)

zonal_stats0915=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201509_bil.bil')
zonal_stats0915 = pd.DataFrame(zonal_stats0915)
zonal_stats0915.columns = ["temp_"+x for x in zonal_stats0915.columns]
zonal_stats0915.index = country.index
zonal_stats0915 = pd.concat([country,zonal_stats0915],axis=1)

zonal_stats1015=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201510_bil.bil')
zonal_stats1015 = pd.DataFrame(zonal_stats1015)
zonal_stats1015.columns = ["temp_"+x for x in zonal_stats1015.columns]
zonal_stats1015.index = country.index
zonal_stats1015 = pd.concat([country,zonal_stats1015],axis=1)

zonal_stats1115=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201511_bil.bil')
zonal_stats1115 = pd.DataFrame(zonal_stats1115)
zonal_stats1115.columns = ["temp_"+x for x in zonal_stats1115.columns]
zonal_stats1115.index = country.index
zonal_stats1115 = pd.concat([country,zonal_stats1115],axis=1)

zonal_stats1215=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2015/PRISM_tmean_stable_4kmM3_201512_bil.bil')
zonal_stats1215 = pd.DataFrame(zonal_stats1215)
zonal_stats1215.columns = ["temp_"+x for x in zonal_stats1215.columns]
zonal_stats1215.index = country.index
zonal_stats1215 = pd.concat([country,zonal_stats1215],axis=1)



zonal_stats0115['month']=1
zonal_stats0215['month']=2
zonal_stats0315['month']=3
zonal_stats0415['month']=4
zonal_stats0515['month']=5
zonal_stats0615['month']=6
zonal_stats0715['month']=7
zonal_stats0815['month']=8
zonal_stats0915['month']=9
zonal_stats1015['month']=10
zonal_stats1115['month']=11
zonal_stats1215['month']=12


zonal_stats15=copy.deepcopy(zonal_stats0115)
zonal_stats15=zonal_stats15.append([zonal_stats0215,zonal_stats0315,zonal_stats0415,zonal_stats0515,zonal_stats0615,\
                                   zonal_stats0715,zonal_stats0815,zonal_stats0915,zonal_stats1015,\
                                   zonal_stats1115,zonal_stats1215],ignore_index=True)

zonal_stats15['year']=2015

# %%
##Zonal stats for 01/16-04/16
zonal_stats0116=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201601_bil.bil')
zonal_stats0116 = pd.DataFrame(zonal_stats0116)
zonal_stats0116.columns = ["temp_"+x for x in zonal_stats0116.columns]
zonal_stats0116.index = country.index
zonal_stats0116 = pd.concat([country,zonal_stats0116],axis=1)

zonal_stats0216=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201602_bil.bil')
zonal_stats0216 = pd.DataFrame(zonal_stats0216)
zonal_stats0216.columns = ["temp_"+x for x in zonal_stats0216.columns]
zonal_stats0216.index = country.index
zonal_stats0216 = pd.concat([country,zonal_stats0216],axis=1)

zonal_stats0316=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201603_bil.bil')
zonal_stats0316 = pd.DataFrame(zonal_stats0316)
zonal_stats0316.columns = ["temp_"+x for x in zonal_stats0316.columns]
zonal_stats0316.index = country.index
zonal_stats0316 = pd.concat([country,zonal_stats0316],axis=1)

zonal_stats0416=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201604_bil.bil')
zonal_stats0416 = pd.DataFrame(zonal_stats0416)
zonal_stats0416.columns = ["temp_"+x for x in zonal_stats0416.columns]
zonal_stats0416.index = country.index
zonal_stats0416 = pd.concat([country,zonal_stats0416],axis=1)

zonal_stats0516=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201605_bil.bil')
zonal_stats0516 = pd.DataFrame(zonal_stats0516)
zonal_stats0516.columns = ["temp_"+x for x in zonal_stats0516.columns]
zonal_stats0516.index = country.index
zonal_stats0516 = pd.concat([country,zonal_stats0516],axis=1)

zonal_stats0616=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201606_bil.bil')
zonal_stats0616 = pd.DataFrame(zonal_stats0616)
zonal_stats0616.columns = ["temp_"+x for x in zonal_stats0616.columns]
zonal_stats0616.index = country.index
zonal_stats0616 = pd.concat([country,zonal_stats0616],axis=1)

zonal_stats0716=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201607_bil.bil')
zonal_stats0716 = pd.DataFrame(zonal_stats0716)
zonal_stats0716.columns = ["temp_"+x for x in zonal_stats0716.columns]
zonal_stats0716.index = country.index
zonal_stats0716 = pd.concat([country,zonal_stats0716],axis=1)

zonal_stats0816=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201608_bil.bil')
zonal_stats0816 = pd.DataFrame(zonal_stats0816)
zonal_stats0816.columns = ["temp_"+x for x in zonal_stats0816.columns]
zonal_stats0816.index = country.index
zonal_stats0816 = pd.concat([country,zonal_stats0816],axis=1)

zonal_stats0916=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201609_bil.bil')
zonal_stats0916 = pd.DataFrame(zonal_stats0916)
zonal_stats0916.columns = ["temp_"+x for x in zonal_stats0916.columns]
zonal_stats0916.index = country.index
zonal_stats0916 = pd.concat([country,zonal_stats0916],axis=1)

zonal_stats1016=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201610_bil.bil')
zonal_stats1016 = pd.DataFrame(zonal_stats1016)
zonal_stats1016.columns = ["temp_"+x for x in zonal_stats1016.columns]
zonal_stats1016.index = country.index
zonal_stats1016 = pd.concat([country,zonal_stats1016],axis=1)

zonal_stats1116=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201611_bil.bil')
zonal_stats1116 = pd.DataFrame(zonal_stats1116)
zonal_stats1116.columns = ["temp_"+x for x in zonal_stats1116.columns]
zonal_stats1116.index = country.index
zonal_stats1116 = pd.concat([country,zonal_stats1116],axis=1)

zonal_stats1216=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2016/PRISM_tmean_stable_4kmM3_201612_bil.bil')
zonal_stats1216 = pd.DataFrame(zonal_stats1216)
zonal_stats1216.columns = ["temp_"+x for x in zonal_stats1216.columns]
zonal_stats1216.index = country.index
zonal_stats1216 = pd.concat([country,zonal_stats1216],axis=1)



zonal_stats0116['month']=1
zonal_stats0216['month']=2
zonal_stats0316['month']=3
zonal_stats0416['month']=4
zonal_stats0516['month']=5
zonal_stats0616['month']=6
zonal_stats0716['month']=7
zonal_stats0816['month']=8
zonal_stats0916['month']=9
zonal_stats1016['month']=10
zonal_stats1116['month']=11
zonal_stats1216['month']=12


zonal_stats16=copy.deepcopy(zonal_stats0116)
zonal_stats16=zonal_stats16.append([zonal_stats0216,zonal_stats0316,zonal_stats0416,zonal_stats0516,zonal_stats0616,\
                                   zonal_stats0716,zonal_stats0816,zonal_stats0916,zonal_stats1016,\
                                   zonal_stats1116,zonal_stats1216],ignore_index=True)

zonal_stats16['year']=2016

# %%
##Zonal stats for 01/17-04/17
zonal_stats0117=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201701_bil.bil')
zonal_stats0117 = pd.DataFrame(zonal_stats0117)
zonal_stats0117.columns = ["temp_"+x for x in zonal_stats0117.columns]
zonal_stats0117.index = country.index
zonal_stats0117 = pd.concat([country,zonal_stats0117],axis=1)

zonal_stats0217=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201702_bil.bil')
zonal_stats0217 = pd.DataFrame(zonal_stats0217)
zonal_stats0217.columns = ["temp_"+x for x in zonal_stats0217.columns]
zonal_stats0217.index = country.index
zonal_stats0217 = pd.concat([country,zonal_stats0217],axis=1)

zonal_stats0317=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201703_bil.bil')
zonal_stats0317 = pd.DataFrame(zonal_stats0317)
zonal_stats0317.columns = ["temp_"+x for x in zonal_stats0317.columns]
zonal_stats0317.index = country.index
zonal_stats0317 = pd.concat([country,zonal_stats0317],axis=1)

zonal_stats0417=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201704_bil.bil')
zonal_stats0417 = pd.DataFrame(zonal_stats0417)
zonal_stats0417.columns = ["temp_"+x for x in zonal_stats0417.columns]
zonal_stats0417.index = country.index
zonal_stats0417 = pd.concat([country,zonal_stats0417],axis=1)

zonal_stats0517=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201705_bil.bil')
zonal_stats0517 = pd.DataFrame(zonal_stats0517)
zonal_stats0517.columns = ["temp_"+x for x in zonal_stats0517.columns]
zonal_stats0517.index = country.index
zonal_stats0517 = pd.concat([country,zonal_stats0517],axis=1)

zonal_stats0617=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201706_bil.bil')
zonal_stats0617 = pd.DataFrame(zonal_stats0617)
zonal_stats0617.columns = ["temp_"+x for x in zonal_stats0617.columns]
zonal_stats0617.index = country.index
zonal_stats0617 = pd.concat([country,zonal_stats0617],axis=1)

zonal_stats0717=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201707_bil.bil')
zonal_stats0717 = pd.DataFrame(zonal_stats0717)
zonal_stats0717.columns = ["temp_"+x for x in zonal_stats0717.columns]
zonal_stats0717.index = country.index
zonal_stats0717 = pd.concat([country,zonal_stats0717],axis=1)

zonal_stats0817=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201708_bil.bil')
zonal_stats0817 = pd.DataFrame(zonal_stats0817)
zonal_stats0817.columns = ["temp_"+x for x in zonal_stats0817.columns]
zonal_stats0817.index = country.index
zonal_stats0817 = pd.concat([country,zonal_stats0817],axis=1)

zonal_stats0917=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201709_bil.bil')
zonal_stats0917 = pd.DataFrame(zonal_stats0917)
zonal_stats0917.columns = ["temp_"+x for x in zonal_stats0917.columns]
zonal_stats0917.index = country.index
zonal_stats0917 = pd.concat([country,zonal_stats0917],axis=1)

zonal_stats1017=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201710_bil.bil')
zonal_stats1017 = pd.DataFrame(zonal_stats1017)
zonal_stats1017.columns = ["temp_"+x for x in zonal_stats1017.columns]
zonal_stats1017.index = country.index
zonal_stats1017 = pd.concat([country,zonal_stats1017],axis=1)

zonal_stats1117=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201711_bil.bil')
zonal_stats1117 = pd.DataFrame(zonal_stats1117)
zonal_stats1117.columns = ["temp_"+x for x in zonal_stats1117.columns]
zonal_stats1117.index = country.index
zonal_stats1117 = pd.concat([country,zonal_stats1117],axis=1)

zonal_stats1217=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2017/PRISM_tmean_stable_4kmM3_201712_bil.bil')
zonal_stats1217 = pd.DataFrame(zonal_stats1217)
zonal_stats1217.columns = ["temp_"+x for x in zonal_stats1217.columns]
zonal_stats1217.index = country.index
zonal_stats1217 = pd.concat([country,zonal_stats1217],axis=1)



zonal_stats0117['month']=1
zonal_stats0217['month']=2
zonal_stats0317['month']=3
zonal_stats0417['month']=4
zonal_stats0517['month']=5
zonal_stats0617['month']=6
zonal_stats0717['month']=7
zonal_stats0817['month']=8
zonal_stats0917['month']=9
zonal_stats1017['month']=10
zonal_stats1117['month']=11
zonal_stats1217['month']=12


zonal_stats17=copy.deepcopy(zonal_stats0117)
zonal_stats17=zonal_stats17.append([zonal_stats0217,zonal_stats0317,zonal_stats0417,zonal_stats0517,zonal_stats0617,\
                                   zonal_stats0717,zonal_stats0817,zonal_stats0917,zonal_stats1017,\
                                   zonal_stats1117,zonal_stats1217],ignore_index=True)

zonal_stats17['year']=2017

# %%
#Zonal stats for 01/18-04/18
zonal_stats0118=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2018/PRISM_tmean_stable_4kmM3_201801_bil.bil')
zonal_stats0118 = pd.DataFrame(zonal_stats0118)
zonal_stats0118.columns = ["temp_"+x for x in zonal_stats0118.columns]
zonal_stats0118.index = country.index
zonal_stats0118 = pd.concat([country,zonal_stats0118],axis=1)

zonal_stats0218=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2018/PRISM_tmean_stable_4kmM3_201802_bil.bil')
zonal_stats0218 = pd.DataFrame(zonal_stats0218)
zonal_stats0218.columns = ["temp_"+x for x in zonal_stats0218.columns]
zonal_stats0218.index = country.index
zonal_stats0218 = pd.concat([country,zonal_stats0218],axis=1)

zonal_stats0318=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2018/PRISM_tmean_stable_4kmM3_201803_bil.bil')
zonal_stats0318 = pd.DataFrame(zonal_stats0318)
zonal_stats0318.columns = ["temp_"+x for x in zonal_stats0318.columns]
zonal_stats0318.index = country.index
zonal_stats0318 = pd.concat([country,zonal_stats0318],axis=1)

zonal_stats0418=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2018/PRISM_tmean_stable_4kmM3_201804_bil.bil')
zonal_stats0418 = pd.DataFrame(zonal_stats0418)
zonal_stats0418.columns = ["temp_"+x for x in zonal_stats0418.columns]
zonal_stats0418.index = country.index
zonal_stats0418 = pd.concat([country,zonal_stats0418],axis=1)

zonal_stats0518=zonal_stats(country, '/Users/noahgonzales/Desktop/PRISM/2018/PRISM_tmean_stable_4kmM3_201805_bil.bil')
zonal_stats0518 = pd.DataFrame(zonal_stats0518)
zonal_stats0518.columns = ["temp_"+x for x in zonal_stats0518.columns]
zonal_stats0518.index = country.index
zonal_stats0518 = pd.concat([country,zonal_stats0518],axis=1)




zonal_stats0118['month']=1
zonal_stats0218['month']=2
zonal_stats0318['month']=3
zonal_stats0418['month']=4
zonal_stats0518['month']=5


zonal_stats18=copy.deepcopy(zonal_stats0118)
zonal_stats18=zonal_stats18.append([zonal_stats0218,zonal_stats0318,zonal_stats0418,zonal_stats0518],ignore_index=True)

zonal_stats18['year']=2018

# %%
zonal_stats_full=zonal_stats08.append([zonal_stats09,zonal_stats10, zonal_stats11,zonal_stats12,zonal_stats13,\
                                       zonal_stats14,zonal_stats15,zonal_stats16,zonal_stats17,zonal_stats18],\
                                      ignore_index=True)
#zonal_stats_full

# %%
zonal_stats_full
# Out:
#            GEO_ID STATE          NAME LSAD  CENSUSAREA  \
# 0     0400000US17    17      Illinois        55518.930
# 1     0400000US18    18       Indiana        35826.109
# 2     0400000US19    19          Iowa        55857.130
# 3     0400000US20    20        Kansas        81758.717
# 4     0400000US27    27     Minnesota        79626.743
# ...           ...   ...           ...  ...         ...
# 1245  0400000US29    29      Missouri        68741.522
# 1246  0400000US31    31      Nebraska        76824.171
# 1247  0400000US39    39          Ohio        40860.694
# 1248  0400000US46    46  South Dakota        75811.000
# 1249  0400000US55    55     Wisconsin        54157.805
#
#                                                geometry   temp_min   temp_max  \
# 0     POLYGON ((-89.36603 42.50027, -89.36156 42.500...  -8.770000   1.531000
# 1     POLYGON ((-84.80249 40.52805, -84.80255 40.501...  -4.990000   1.499000
# ...

# %%
monthly_temp_mean=zonal_stats_full.groupby(['year', 'month'])['temp_mean'].mean()
monthly_temp_mean=pd.DataFrame(monthly_temp_mean)
monthly_temp_mean=monthly_temp_mean.reset_index()
monthly_temp_mean=monthly_temp_mean.rename(columns={'temp_mean':'temp_mean_full'})
monthly_temp_mean.head(5)
# Out:
#    year  month  temp_mean_full
# 0  2008      1       -5.696605
# 1  2008      2       -5.385649
# 2  2008      3        1.371196
# 3  2008      4        8.364493
# 4  2008      5       13.805880

# %%
monthly_temp_mean.count()
# Out:
# year              124
# month             124
# temp_mean_full    124
# dtype: int64

# %%
zonal_stats_full=zonal_stats_full.merge(monthly_temp_mean,on=['year','month'],how='outer')
zonal_stats_full['temp_difference']=zonal_stats_full['temp_mean']-zonal_stats_full['temp_mean_full']
zonal_stats_full
# Out:
#            GEO_ID STATE          NAME LSAD  CENSUSAREA  \
# 0     0400000US17    17      Illinois        55518.930
# 1     0400000US18    18       Indiana        35826.109
# 2     0400000US19    19          Iowa        55857.130
# 3     0400000US20    20        Kansas        81758.717
# 4     0400000US27    27     Minnesota        79626.743
# ...           ...   ...           ...  ...         ...
# 1245  0400000US29    29      Missouri        68741.522
# 1246  0400000US31    31      Nebraska        76824.171
# 1247  0400000US39    39          Ohio        40860.694
# 1248  0400000US46    46  South Dakota        75811.000
# 1249  0400000US55    55     Wisconsin        54157.805
#
#                                                geometry   temp_min   temp_max  \
# 0     POLYGON ((-89.36603 42.50027, -89.36156 42.500...  -8.770000   1.531000
# 1     POLYGON ((-84.80249 40.52805, -84.80255 40.501...  -4.990000   1.499000
# ...

# %%
monthly_temp_mean=zonal_stats_full.groupby(['NAME', 'month'])['temp_mean'].mean()
monthly_temp_mean=pd.DataFrame(monthly_temp_mean)
monthly_temp_mean=monthly_temp_mean.reset_index()
monthly_temp_mean=monthly_temp_mean.rename(columns={'temp_mean':'temp_mean_full'})
monthly_temp_mean.head()

# %%
zonal_stats_full=zonal_stats_full.merge(monthly_temp_mean,on=['NAME','month'],how='outer')
zonal_stats_full['temp_difference']=zonal_stats_full['temp_mean']-zonal_stats_full['temp_mean_full']
zonal_stats_full
